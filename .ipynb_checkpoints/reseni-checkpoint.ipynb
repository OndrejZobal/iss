# %%
import numpy as np
import soundfile as sf
from IPython.display import display
from IPython.display import Audio
import matplotlib.pyplot as plt
import scipy

# %%
MIDIFROM = 24
MIDITO = 108
SKIP_SEC = 0.25
HOWMUCH_SEC = 0.5
WHOLETONE_SEC = 2

# %%
# My signals
NOTES = [36, 47, 87]
NOTE_FREQS = [65.41, 123.47, 1244.52]

# %%
howmanytones = MIDITO - MIDIFROM + 1
tones = np.arange(MIDIFROM, MIDITO+1)
s, Fs = sf.read('../audio/klavir.wav')
N = int(Fs * HOWMUCH_SEC)
Nwholetone = int(Fs * WHOLETONE_SEC)
xall = np.zeros((MIDITO+1, N))
 # matrix with all tones - first signals empty,
# but we have plenty of memory ...

# %%
samplefrom = int(SKIP_SEC * Fs)
sampleto = samplefrom + N
for tone in tones:
    x = s[samplefrom:sampleto]
    x = x - np.mean(x)
    # safer to center ...
    xall[tone,:] = x
    samplefrom += Nwholetone
    sampleto += Nwholetone

# %% [markdown]
# #  4.1 Základy

# %%
PERIOD_REPEAT = 3

# Coputing dft for all notes 
spectrum = np.zeros([MIDITO+1, Fs//2], dtype=complex)
for note in range(MIDIFROM, MIDITO+1):
    spectrum[note] = np.fft.fft(xall[note])

# Iterate through my MIDI
for i, note in enumerate(NOTES):
    print(f"Audio of note {i} (MIDI {note}):")
    display(Audio(xall[note][int(Fs * SKIP_SEC) : int(Fs * (SKIP_SEC+HOWMUCH_SEC))], rate=Fs))
    left_bound = 0
    right_bound = left_bound + int(Fs / NOTE_FREQS[i]) * PERIOD_REPEAT

    sample = xall[note][left_bound:right_bound]
    
    # Signal
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    ax.set_title(f"Signal of MIDI {note}")
    ax.set_xlabel(f"Time $[s]$")
    ax.set_ylabel(f"Amplitude")
    ax.plot(sample)
    ax.grid()
    plt.tight_layout()
    
    # Spectrum
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    s = np.log10(np.abs(spectrum[note]) ** 2)
    s[0] = 0.00001
    ax.set_title(f"Spectrum of MIDI {note}")
    ax.set_xlabel(f"Frequency $[Hz]$")
    ax.set_ylabel(f"Mag. $[db]$")
    ax.plot(np.real(s[:s.size//2]))
    ax.grid()
    plt.tight_layout()
# Out:
# Audio of note 0 (MIDI 36):
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio of note 1 (MIDI 47):
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio of note 2 (MIDI 87):
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 4.2 Určení základní frekvence
#
# Do MIDI 60 používám metodu autokorelace, z jejiž délky mezi vrcholi získám proměnnou *p*, kterou pak převádím na frekvenci následovně:
# $$
# \verb|freq| = \frac{1}{p} \cdot F_s
# $$
#
# Na zbytek hodnot používám DFT. Zde stačí najít maxima absolutní hodnoty a dosadit jako *m* do následujícího vzorce:
# $$
# \verb|freq| = m \cdot \frac{F_s}{N}
# $$

# %%
# Returns index of the highest element in the array.
def max_index(array):
    i = 0
    val = array[0]
    for index, a_val in enumerate(array):
        if a_val >= val:
            i = index
            val = a_val
    return i

# %%
def compute_base_autocor(array, plot):
    corelate = scipy.signal.correlate(array, array, mode='same')
    corelate = corelate[corelate.size//2:]
    peaks = scipy.signal.find_peaks(corelate, height=max(corelate)/1.3)[0]
    period = np.abs(peaks[0]-peaks[1])
    
    if plot:
        # TODO Highlight somehow 
        fig = plt.figure(figsize=(20, 7))
        ax = fig.add_subplot(111)
        ax.set_title(f"Signal of MIDI {note}")
        ax.set_xlabel(f"Frequency $[Hz]$")
        ax.set_ylabel(f"Mag. $[db]$")
        ax.plot(corelate)
        ax.grid()
        plt.tight_layout()
    
    return 1/period*Fs
    

def compute_base_dft(array, spectrum, plot):
    maximal = max_index(abs(spectrum[:spectrum.size//2]))
    if plot:
        fig = plt.figure(figsize=(20, 7))
        ax = fig.add_subplot(111)
        ax.set_title(f"Base frequency shown in signal of MIDI {note}")
        ax.set_xlabel(f"Frequency $[Hz]$")
        ax.set_ylabel(f"Mag. $[db]$")
        s = np.log10(np.abs(spectrum) ** 2)
        s[0]=0
        # Unhinged height hack
        ax.plot(np.real(maximal), max(abs(s[int(np.real(maximal))-5: int(np.real(maximal)+5)])), "ro")
        ax.plot(s[:s.size//2])
        ax.grid()
        plt.tight_layout()
    return maximal * (Fs / array.size)

# %%
# Iterate through all notes
bases = np.zeros(MIDITO+1)
DFT_FROM = 60
for note_index in range(MIDIFROM, MIDITO+1):
    if note_index < DFT_FROM:
        base = compute_base_autocor(xall[note_index], (note_index in NOTES))
    else:
        base = compute_base_dft(xall[note_index], spectrum[note_index], (note_index in NOTES))
    print(f"MIDI {note_index} base frequency is {base}")
    bases[note_index] = base
# Out:
# MIDI 24 base frequency is 32.76450511945392
# MIDI 25 base frequency is 34.73227206946454
# MIDI 26 base frequency is 36.7816091954023
# MIDI 27 base frequency is 38.961038961038966
# MIDI 28 base frequency is 41.2725709372313
# MIDI 29 base frequency is 43.71584699453552
# MIDI 30 base frequency is 46.33204633204633
# MIDI 31 base frequency is 49.079754601227
# MIDI 32 base frequency is 51.94805194805195
# MIDI 33 base frequency is 55.10907003444317
# MIDI 34 base frequency is 58.3232077764277
# MIDI 35 base frequency is 61.855670103092784
# MIDI 36 base frequency is 65.57377049180327
# MIDI 37 base frequency is 69.46454413892909
# MIDI 38 base frequency is 73.50689127105666
# MIDI 39 base frequency is 77.92207792207793
# MIDI 40 base frequency is 82.47422680412372
# MIDI 41 base frequency is 87.5912408759124
# MIDI 42 base frequency is 93.02325581395348
# MIDI 43 base frequency is 98.56262833675565
# MIDI 44 base frequency is 104.12147505422993
# MIDI 45 base frequency is 110.34482758620689
# MIDI 46 base frequency is 117.07317073170732
# MIDI 47 base frequency is 123.39331619537275
# MIDI 48 base frequency is 130.7901907356948
# MIDI 49 base frequency is 138.72832369942196
# MIDI 50 base frequency is 146.78899082568807
# MIDI 51 base frequency is 155.33980582524273
# MIDI 52 base frequency is 164.94845360824743
# MIDI 53 base frequency is 174.54545454545453
# MIDI 54 base frequency is 185.32818532818533
# MIDI 55 base frequency is 195.9183673469388
# MIDI 56 base frequency is 208.69565217391303
# MIDI 57 base frequency is 221.19815668202764
# MIDI 58 base frequency is 233.00970873786406
# MIDI 59 base frequency is 247.42268041237114
# MIDI 60 base frequency is 262.0
# MIDI 61 base frequency is 278.0
# MIDI 62 base frequency is 294.0
# MIDI 63 base frequency is 312.0
# MIDI 64 base frequency is 330.0
# MIDI 65 base frequency is 350.0
# MIDI 66 base frequency is 370.0
# MIDI 67 base frequency is 392.0
# MIDI 68 base frequency is 416.0
# MIDI 69 base frequency is 440.0
# MIDI 70 base frequency is 466.0
# MIDI 71 base frequency is 494.0
# MIDI 72 base frequency is 524.0
# MIDI 73 base frequency is 554.0
# MIDI 74 base frequency is 588.0
# MIDI 75 base frequency is 622.0
# MIDI 76 base frequency is 660.0
# MIDI 77 base frequency is 698.0
# MIDI 78 base frequency is 740.0
# MIDI 79 base frequency is 784.0
# MIDI 80 base frequency is 830.0
# MIDI 81 base frequency is 882.0
# MIDI 82 base frequency is 932.0
# MIDI 83 base frequency is 988.0
# MIDI 84 base frequency is 1046.0
# MIDI 85 base frequency is 1108.0
# MIDI 86 base frequency is 1174.0
# MIDI 87 base frequency is 1244.0
# MIDI 88 base frequency is 1318.0
# MIDI 89 base frequency is 1396.0
# MIDI 90 base frequency is 1478.0
# MIDI 91 base frequency is 1566.0
# MIDI 92 base frequency is 1660.0
# MIDI 93 base frequency is 1758.0
# MIDI 94 base frequency is 1864.0
# MIDI 95 base frequency is 1976.0
# MIDI 96 base frequency is 2094.0
# MIDI 97 base frequency is 2218.0
# MIDI 98 base frequency is 2350.0
# MIDI 99 base frequency is 2490.0
# MIDI 100 base frequency is 2638.0
# MIDI 101 base frequency is 2796.0
# MIDI 102 base frequency is 2962.0
# MIDI 103 base frequency is 3138.0
# MIDI 104 base frequency is 3324.0
# MIDI 105 base frequency is 3522.0
# MIDI 106 base frequency is 3732.0
# MIDI 107 base frequency is 3954.0
# MIDI 108 base frequency is 4188.0

# %% [markdown]
# # 4.3 Zpřesnění odhadu základní frekvence `f0`

# %%
FREQRANGE = 2
# Like a resolution of the calculation
FREQPOINTS = 80
# For every MIDI base frequency estimate

def dtft(freq, signal):
    
    spectrum_dtft = np.zeros([FREQPOINTS, N], dtype=complex)
    fsweep = np.linspace(np.abs(freq)-FREQRANGE + 1j, np.abs(freq)+FREQRANGE +1j, FREQPOINTS)
    for j in np.arange(0, FREQPOINTS):
        spectrum_dtft[j,:] = np.exp(-1j * 2 * np.pi * fsweep[j] / Fs * np.arange(0,N))
    spec = np.matmul(spectrum_dtft, signal.T)
    index = np.argmax(np.abs(spec))
    mod_phase = spec[index]
    f = np.real(fsweep[index])
    return (mod_phase, f)

# Only applying dtft to results computed by dft
for i in range(DFT_FROM, MIDITO+1):
    mod_phase, bases[i] = dtft(bases[i], xall[i])
    print("hah", mod_phase)
    
    print(f"Accourate estimate for midi {i} is {bases[i]}Hz")
# Out:
# hah (-5788.698695451445+2850.316115521622j)
# Accourate estimate for midi 60 is 261.7721518987342Hz
# hah (-2869.4423453973586+5542.983587176811j)
# Accourate estimate for midi 61 is 277.3164556962025Hz
# hah (1746.6693609968145+2866.941037219349j)
# Accourate estimate for midi 62 is 293.62025316455697Hz
# hah (-3038.361573741644-307.5075188737688j)
# Accourate estimate for midi 94 is 1863.7721518987341Hz
# hah (276.3956018315324+17.81822527041584j)
# Accourate estimate for midi 95 is 1976.4810126582279Hz
# hah (-210.21343523914257+139.3666689064702j)
# Accourate estimate for midi 96 is 2093.9240506329115Hz
# hah (-225.95145782679663-56.86818311344349j)
# Accourate estimate for midi 97 is 2218.4303797468356Hz
# hah (-120.9435677291354-217.54700719290977j)
# Accourate estimate for midi 98 is 2350.5822784810125Hz
# hah (-174.4414154185133-137.50413839533434j)
# Accourate estimate for midi 99 is 2490.3797468354433Hz
# hah (-140.48923101097606-135.1801345098278j)
# Accourate estimate for midi 100 is 2638.53164556962Hz
# hah (107.70062669674485+65.7442333134722j)
# Accourate estimate for midi 101 is 2795.1139240506327Hz
# hah (-74.66701883427585-85.4200876101319j)
# Accourate estimate for midi 102 is 2961.3164556962024Hz
# hah (-49.643248621111255-88.28973220514688j)
# Accourate estimate for midi 103 is 3137.4177215189875Hz
# hah (106.99469130441275+0.6579843590497491j)
# Accourate estimate for midi 104 is 3324.025316455696Hz
# hah (-81.06852251814185+47.17756602456796j)
# Accourate estimate for midi 105 is 3521.6708860759495Hz
# hah (12.388046662726339-80.16197301522726j)
# Accourate estimate for midi 106 is 3731.1139240506327Hz
# hah (-37.533178897921026+81.98326661362164j)
# Accourate estimate for midi 107 is 3953.1645569620255Hz
# hah (67.30732037547304+38.94603353924226j)
# Accourate estimate for midi 108 is 4188.227848101265Hz

# %% [markdown]
# # 4.4 Reprezentace klavíru

# %%
synt_tones = np.zeros([bases.size, 5, 2])
synt_freq  = np.zeros([bases.size, 5])

for note in range(MIDIFROM, MIDITO+1):
    kall = np.arange(0,int(spectrum[note].size))
    phase = np.angle(spectrum[note][kall])
    mod = np.abs(spectrum[note][kall])

    for i in range(1, 6):
        mod_phase, freq = dtft(bases[note] * i, xall[note])
        synt_tones[note][i-1][0] = np.abs(mod_phase)
        synt_tones[note][i-1][1] = np.angle(mod_phase)
        synt_freq[note][i-1] = freq

    print(synt_tones[note])
# Out:
# [[ 3.04191317e+02  2.07770051e+00]
#  [ 6.87641153e+03 -2.37403037e-01]
#  [ 4.21570234e+03  1.06843848e-01]
#  [ 3.28368894e+03  4.86324437e-01]
#  [ 1.98531860e+03 -2.77145750e+00]]
# [[ 2.11098291e+02 -1.56165413e-01]
#  [ 6.71689120e+03 -4.33707355e-01]
#  [ 3.95000647e+03  2.89654092e+00]
#  [ 3.25041372e+03 -3.89136937e-02]
#  [ 2.23112098e+03 -2.50907343e-01]]
# [[ 1.64088644e+02  2.88378016e+00]
#  [ 6.68264399e+03 -3.06811743e-01]
#  [ 3.98260426e+03  5.91111736e-02]
#  [ 3.06266468e+03  4.99288899e-01]
#  [ 1.96321321e+03 -2.71620565e+00]]
# [[ 2.31025196e+02 -2.24540525e+00]
#  [ 6.59012396e+03  2.61405197e-01]
#  [ 4.02055060e+03 -2.24230424e+00]
#  [ 3.25326845e+03  1.64151328e+00]
#  [ 1.90373352e+03  1.96523154e+00]]
# [[ 2.75774081e+02  2.84539262e+00]
#  [ 6.27238323e+03  1.33468106e+00]
#  [ 1.38381186e-02 -4.27249935e-01]
#  [ 2.59446659e-02  1.23471840e+00]
#  [ 1.45189505e-02  1.54885083e+00]]
# [[ 9.38111493e+01  2.56811859e+00]
#  [ 1.09864145e-01 -2.04239541e+00]
#  [ 1.53559412e-02  2.20873020e+00]
#  [ 1.40127163e-02  2.01530795e+00]
#  [ 1.02328723e-02  1.46204298e+00]]
# [[ 8.11210814e+01 -1.46313758e+00]
#  [ 8.97849413e-02 -2.88839412e+00]
#  [ 9.78591306e-03  1.69070742e+00]
#  [ 1.49459296e-02 -7.53027861e-01]
#  [ 1.48383958e-02 -4.70413503e-01]]
# [[ 9.01488686e+01  2.04636767e+00]
#  [ 4.96945334e-02  3.00317057e+00]
#  [ 9.86117760e-03 -5.47433580e-01]
#  [ 1.88719418e-02  3.60988210e-01]
#  [ 1.42634051e-02  1.61687736e-01]]
# [[ 7.77585991e+01  5.70325466e-01]
#  [ 6.55740803e-02 -2.49684172e-01]
#  [ 2.57091460e-02  2.69367005e-01]
#  [ 1.26274230e-02 -9.05465064e-01]
#  [ 1.55856350e-02 -9.23667921e-01]]

# %%
for note in NOTES:
    s = np.log10(np.abs(spectrum[note]) ** 2)
    s[0]=0.00005
    
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    ax.set_title(f"Spectrum of MIDI {note}")
    ax.set_xlabel(f"Frequency $[Hz]$")
    ax.set_ylabel(f"Mag. $[db]$")
    for index, tone in enumerate(synt_tones[note]):
        print(tone[0], s)
        ax.plot(tone[0], s[int(tone[0])], "ro")
        ax.plot()
    ax.plot(s[:s.size//2])
    ax.grid()
    plt.tight_layout()
# Out:
# 188.05170879043436 [5.00000000e-05 1.09907750e+00 1.26002600e+00 ... 1.09250609e+00
#  1.26002600e+00 1.09907750e+00]
# 5924.276974478413 [5.00000000e-05 1.09907750e+00 1.26002600e+00 ... 1.09250609e+00
#  1.26002600e+00 1.09907750e+00]
# 2114.7452195295537 [5.00000000e-05 1.09907750e+00 1.26002600e+00 ... 1.09250609e+00
#  1.26002600e+00 1.09907750e+00]
# 2245.2639541274452 [5.00000000e-05 1.09907750e+00 1.26002600e+00 ... 1.09250609e+00
#  1.26002600e+00 1.09907750e+00]
# 944.9068483841672 [5.00000000e-05 1.09907750e+00 1.26002600e+00 ... 1.09250609e+00
#  1.26002600e+00 1.09907750e+00]
# 7835.910697223697 [5.00000000e-05 2.01643496e+00 2.02082731e+00 ... 1.91451143e+00
#  2.02082731e+00 2.01643496e+00]
# 872.3030766580573 [5.00000000e-05 2.01643496e+00 2.02082731e+00 ... 1.91451143e+00
#  2.02082731e+00 2.01643496e+00]
# 1659.4886976036776 [5.00000000e-05 2.01643496e+00 2.02082731e+00 ... 1.91451143e+00
#  2.02082731e+00 2.01643496e+00]
# 2707.6942243563517 [5.00000000e-05 2.01643496e+00 2.02082731e+00 ... 1.91451143e+00
#  2.02082731e+00 2.01643496e+00]
# 1469.7704842397059 [5.00000000e-05 2.01643496e+00 2.02082731e+00 ... 1.91451143e+00
#  2.02082731e+00 2.01643496e+00]
# 457.94727375232935 [ 5.00000000e-05 -1.70457462e+00 -2.20102551e+00 ... -1.81226444e+00
#  -2.20102551e+00 -1.70457462e+00]
# 13.822812821242838 [ 5.00000000e-05 -1.70457462e+00 -2.20102551e+00 ... -1.81226444e+00
#  -2.20102551e+00 -1.70457462e+00]
# 1.0765186603635095 [ 5.00000000e-05 -1.70457462e+00 -2.20102551e+00 ... -1.81226444e+00
#  -2.20102551e+00 -1.70457462e+00]
# 0.2906953732832511 [ 5.00000000e-05 -1.70457462e+00 -2.20102551e+00 ... -1.81226444e+00
#  -2.20102551e+00 -1.70457462e+00]
# 0.1754406279768977 [ 5.00000000e-05 -1.70457462e+00 -2.20102551e+00 ... -1.81226444e+00
#  -2.20102551e+00 -1.70457462e+00]

# %% [markdown]
# # 4.5 Syntéza tónů

# %%
synt_signal = None
print(synt_tones.size, synt_freq.size)
for index in range(MIDIFROM, MIDITO+1):
    index = NOTES[0]
    spec = np.zeros(Fs//2, dtype=complex)
    for i in range(5):
        spec[int(synt_freq[index][i])] = synt_tones[index][i][0] + synt_tones[index][i][1] * 1j
        print("Frequency, module:", synt_freq[index][i], synt_tones[index][i][0])
    synt_signal = np.fft.ifft(spec)
    print(max(spec))

    
    left_bound = 0
    right_bound = left_bound + int(Fs / NOTE_FREQS[0]) * PERIOD_REPEAT
    sample = synt_signal[left_bound:right_bound]
    # Signal
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    ax.set_title(f"Signal of MIDI {note}")
    ax.set_xlabel(f"Time $[s]$")
    ax.set_ylabel(f"Amplitude")
    ax.plot(sample)
    ax.grid()
    plt.tight_layout()
    
    #spectrum
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    s = spec#np.log10(np.abs(spectrum[note]) ** 2)
    s[0] = 0.00001
    ax.set_title(f"Spectrum of MIDI {note}")
    ax.set_xlabel(f"Frequency $[Hz]$")
    ax.set_ylabel(f"Mag. $[db]$")
    ax.plot(np.real(s[:s.size//2]))
    ax.grid()
    plt.tight_layout()
    
    display(Audio(synt_signal, rate=Fs))
    break
# Out:
# 1090 545
# Frequency, module: 64.99149201079061 188.05170879043436
# Frequency, module: 130.6158954139863 5924.276974478413
# Frequency, module: 196.13903299439718 2114.7452195295537
# Frequency, module: 261.76343639759284 2245.2639541274452
# Frequency, module: 327.3372068893961 944.9068483841672
# (5924.276974478413+1.537642181474475j)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 4.5 Generování hudby

# %%
song = np.zeros([10 * Fs])
song_src = None
with open("../audio/skladba.txt", "r", encoding="utf-8") as f:
    while True:
        song_src = f.readline()
        song_src = song_src.split(' ')
        from_sample = float(song_src[0]) * 1000 / Fs
        to_sample = float(song_src[1]) * 1000 / Fs
        if int(song_src[2]) / 1000 * Fs >= 10*Fs:
            break
        song[int(from_sample):int(to_sample)] += synt_tones[int(song_src[2])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 11
#       9 if int(song_src[2]) / 1000 * Fs >= 10*Fs:
#      10     break
# ---> 11 song[int(from_sample):int(to_sample)] += synt_tones[int(song_src[2])]
#
# ValueError: operands could not be broadcast together with shapes (18,) (5,2) (18,)
