# %%
import numpy as np
import soundfile as sf
from IPython.display import display
from IPython.display import Audio
import matplotlib.pyplot as plt
import scipy

# %%
MIDIFROM = 24
MIDITO = 108
SKIP_SEC = 0.25
HOWMUCH_SEC = 0.5
WHOLETONE_SEC = 2

# %%
# My signals
NOTES = [36, 47, 87]
NOTE_FREQS = [65.41, 123.47, 1244.52]

# %%
howmanytones = MIDITO - MIDIFROM + 1
tones = np.arange(MIDIFROM, MIDITO+1)
s, Fs = sf.read('../audio/klavir.wav')
N = int(Fs * HOWMUCH_SEC)
Nwholetone = int(Fs * WHOLETONE_SEC)
xall = np.zeros((MIDITO+1, N))
 # matrix with all tones - first signals empty,
# but we have plenty of memory ...

# %%
samplefrom = int(SKIP_SEC * Fs)
sampleto = samplefrom + N
for tone in tones:
    x = s[samplefrom:sampleto]
    x = x - np.mean(x)
    # safer to center ...
    xall[tone,:] = x
    samplefrom += Nwholetone
    sampleto += Nwholetone

# %% [markdown]
# #  4.1 Základy

# %%
PERIOD_REPEAT = 3
# Iterate through my MIDI
for i, note in enumerate(NOTES):
    print(f"Audio of note {i} (MIDI {note}):")
    display(Audio(xall[note][int(Fs * SKIP_SEC) : int(Fs * (SKIP_SEC+HOWMUCH_SEC))], rate=Fs))
    left_bound = 0
    right_bound = left_bound + int(Fs / NOTE_FREQS[i]) * PERIOD_REPEAT

    sample = xall[note][left_bound:right_bound]
    
    # Signal
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    ax.set_title(f"Signal of MIDI {note}")
    ax.set_xlabel(f"Time $[s]$")
    ax.set_ylabel(f"Amplitude")
    ax.plot(sample)
    ax.grid()
    plt.tight_layout()
    
    # Spectrum
    # TODO Plot logarithmically
    spectrum = np.fft.fft(xall[note])
    fig = plt.figure(figsize=(20, 7))
    ax = fig.add_subplot(111)
    spectrum = np.log10(np.abs(spectrum) ** 2)
    spectrum[0]=0
    ax.set_title(f"Spectrum of MIDI {note}")
    ax.set_xlabel(f"Frequency $[Hz]$")
    ax.set_ylabel(f"Mag. $[db]$")
    ax.plot(abs(np.real(spectrum[:spectrum.size//2])))
    ax.grid()
    plt.tight_layout()
# Out:
# Audio of note 0 (MIDI 36):
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio of note 1 (MIDI 47):
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio of note 2 (MIDI 87):
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 4.2 Určení základní frekvence
#
# Do MIDI 60 používám metodu autokorelace, z jejiž délky mezi vrcholi získám proměnnou *p*, kterou pak převádím na frekvenci následovně:
# $$
# \verb|freq| = \frac{1}{p} \cdot F_s
# $$
#
# Na zbytek hodnot používám DFT. Zde stačí najít maxima absolutní hodnoty a dosadit jako *m* do následujícího vzorce:
# $$
# \verb|freq| = m \cdot \frac{F_s}{N}
# $$

# %%
def compute_base_autocor(array, plot):
    corelate = scipy.signal.correlate(array, array, mode='same')
    corelate = corelate[corelate.size//2:]
    peaks = scipy.signal.find_peaks(corelate, height=max(corelate)/1.3)[0]
    period = abs(peaks[0]-peaks[1])

    if plot:
        # TODO Highlight somehow 
        fig = plt.figure(figsize=(20, 7))
        ax = fig.add_subplot(111)
        ax.set_title(f"Signal of MIDI {note}")
        ax.set_xlabel(f"Frequency $[Hz]$")
        ax.set_ylabel(f"Mag. $[db]$")
        ax.plot(corelate)
        ax.grid()
        plt.tight_layout()
    
    return 1/period*Fs
    

def compute_base_dft(array, plot):
    spectrum = np.fft.fft(array)
    maximal = np.argmax(abs(spectrum[:spectrum.size//2]))
    if plot:
        fig = plt.figure(figsize=(20, 7))
        ax = fig.add_subplot(111)
        ax.set_title(f"Base frequency shown in signal of MIDI {note}")
        ax.set_xlabel(f"Frequency $[Hz]$")
        ax.set_ylabel(f"Mag. $[db]$")
        s = np.log10(np.abs(spectrum) ** 2)
        s[0]=0
        # Unhinged height hack
        ax.plot(np.real(maximal), max(abs(s[int(np.real(maximal))-5: int(np.real(maximal)+5)])), "ro")
        ax.plot(abs(s[:s.size//2]))
        ax.grid()
        plt.tight_layout()
    return maximal * (Fs / array.size)

# %%
# Iterate through all notes
bases = np.zeros(MIDITO)
for note_index in range(MIDIFROM, MIDITO):
    if note_index <= 60:
        base = compute_base_autocor(xall[note_index], (note_index in NOTES))
    else:
        base = compute_base_dft(xall[note_index], (note_index in NOTES))
    print(f"MIDI {note_index} base frequency is {base}")
    bases[note_index] = base
# Out:
# MIDI 24 base frequency is 32.76450511945392
# MIDI 25 base frequency is 34.73227206946454
# MIDI 26 base frequency is 36.7816091954023
# MIDI 27 base frequency is 38.961038961038966
# MIDI 28 base frequency is 41.2725709372313
# MIDI 29 base frequency is 43.71584699453552
# MIDI 30 base frequency is 46.33204633204633
# MIDI 31 base frequency is 49.079754601227
# MIDI 32 base frequency is 51.94805194805195
# MIDI 33 base frequency is 55.10907003444317
# MIDI 34 base frequency is 58.3232077764277
# MIDI 35 base frequency is 61.855670103092784
# MIDI 36 base frequency is 65.57377049180327
# MIDI 37 base frequency is 69.46454413892909
# MIDI 38 base frequency is 73.50689127105666
# MIDI 39 base frequency is 77.92207792207793
# MIDI 40 base frequency is 82.47422680412372
# MIDI 41 base frequency is 87.5912408759124
# MIDI 42 base frequency is 93.02325581395348
# MIDI 43 base frequency is 98.56262833675565
# MIDI 44 base frequency is 104.12147505422993
# MIDI 45 base frequency is 110.34482758620689
# MIDI 46 base frequency is 117.07317073170732
# MIDI 47 base frequency is 123.39331619537275
# MIDI 48 base frequency is 130.7901907356948
# MIDI 49 base frequency is 138.72832369942196
# MIDI 50 base frequency is 146.78899082568807
# MIDI 51 base frequency is 155.33980582524273
# MIDI 52 base frequency is 164.94845360824743
# MIDI 53 base frequency is 174.54545454545453
# MIDI 54 base frequency is 185.32818532818533
# MIDI 55 base frequency is 195.9183673469388
# MIDI 56 base frequency is 208.69565217391303
# MIDI 57 base frequency is 221.19815668202764
# MIDI 58 base frequency is 233.00970873786406
# MIDI 59 base frequency is 247.42268041237114
# MIDI 60 base frequency is 262.2950819672131
# MIDI 61 base frequency is 278.0
# MIDI 62 base frequency is 294.0
# MIDI 63 base frequency is 312.0
# MIDI 64 base frequency is 330.0
# MIDI 65 base frequency is 350.0
# MIDI 66 base frequency is 370.0
# MIDI 67 base frequency is 392.0
# MIDI 68 base frequency is 416.0
# MIDI 69 base frequency is 440.0
# MIDI 70 base frequency is 466.0
# MIDI 71 base frequency is 494.0
# MIDI 72 base frequency is 524.0
# MIDI 73 base frequency is 554.0
# MIDI 74 base frequency is 588.0
# MIDI 75 base frequency is 622.0
# MIDI 76 base frequency is 660.0
# MIDI 77 base frequency is 698.0
# MIDI 78 base frequency is 740.0
# MIDI 79 base frequency is 784.0
# MIDI 80 base frequency is 830.0
# MIDI 81 base frequency is 882.0
# MIDI 82 base frequency is 932.0
# MIDI 83 base frequency is 988.0
# MIDI 84 base frequency is 1046.0
# MIDI 85 base frequency is 1108.0
# MIDI 86 base frequency is 1174.0
# MIDI 87 base frequency is 1244.0
# MIDI 88 base frequency is 1318.0
# MIDI 89 base frequency is 1396.0
# MIDI 90 base frequency is 1478.0
# MIDI 91 base frequency is 1566.0
# MIDI 92 base frequency is 1660.0
# MIDI 93 base frequency is 1758.0
# MIDI 94 base frequency is 1864.0
# MIDI 95 base frequency is 1976.0
# MIDI 96 base frequency is 2094.0
# MIDI 97 base frequency is 2218.0
# MIDI 98 base frequency is 2350.0
# MIDI 99 base frequency is 2490.0
# MIDI 100 base frequency is 2638.0
# MIDI 101 base frequency is 2796.0
# MIDI 102 base frequency is 2962.0
# MIDI 103 base frequency is 3138.0
# MIDI 104 base frequency is 3324.0
# MIDI 105 base frequency is 3522.0
# MIDI 106 base frequency is 3732.0
# MIDI 107 base frequency is 3954.0

# %% [markdown]
# # 4.3 Zpřesnění odhadu základní frekvence `f0`

# %%
FREQRANGE = 1
# Like a resolution of the calculation
FREQPOINTS = 200
# For every MIDI base frequency estimate

def dtft(freq):
    spectrum = np.zeros([FREQPOINTS, N], dtype=complex)
    fsweep = np.linspace(freq-FREQRANGE, freq+FREQRANGE, FREQPOINTS)
    for j in np.arange(0, FREQPOINTS):
        spectrum[j,:] = np.exp(-1j * 2 * np.pi * fsweep[j] / Fs * np.arange(0,N))
    result = np.matmul(spectrum, xall[i].T)
    result = fsweep[np.argmax(np.abs(result))]
    return result

for i in range(MIDIFROM, MIDITO):
    result = dtft(bases[i])
    print(f"Accourate estimate for midi {i} is {result}Hz")
# Out:
# Accourate estimate for midi 24 is 32.16651516970518Hz
# Accourate estimate for midi 25 is 35.73227206946454Hz
# Accourate estimate for midi 26 is 36.193669496909834Hz
# Accourate estimate for midi 27 is 38.3228480062651Hz
# Accourate estimate for midi 28 is 41.23739505783431Hz
# Accourate estimate for midi 29 is 44.36408820056567Hz
# Accourate estimate for midi 30 is 47.33204633204633Hz
# Accourate estimate for midi 31 is 48.60236766655363Hz
# Accourate estimate for midi 32 is 50.94805194805195Hz
# Accourate estimate for midi 33 is 55.58645696911654Hz
# Accourate estimate for midi 34 is 59.3232077764277Hz
# Accourate estimate for midi 35 is 61.9812982437963Hz
# Accourate estimate for midi 36 is 65.33758958728066Hz
# Accourate estimate for midi 37 is 69.07760946556225Hz
# Accourate estimate for midi 38 is 72.95915257758932Hz
# Accourate estimate for midi 39 is 77.3140377210729Hz
# Accourate estimate for midi 40 is 81.9666891156815Hz
# Accourate estimate for midi 41 is 87.69676851410335Hz
# Accourate estimate for midi 42 is 92.92777842701881Hz
# Accourate estimate for midi 43 is 98.4571006985647Hz
# Accourate estimate for midi 44 is 104.30740470247113Hz
# Accourate estimate for midi 45 is 110.51065673193553Hz
# Accourate estimate for midi 46 is 117.06814560607918Hz
# Accourate estimate for midi 47 is 123.18728604461897Hz
# Accourate estimate for midi 48 is 130.50375857489078Hz
# Accourate estimate for midi 49 is 138.27103726726116Hz
# Accourate estimate for midi 50 is 146.68346318749713Hz
# Accourate estimate for midi 51 is 155.385031955896Hz
# Accourate estimate for midi 52 is 164.611770191162Hz
# Accourate estimate for midi 53 is 174.52032891731383Hz
# Accourate estimate for midi 54 is 184.89099939853708Hz
# Accourate estimate for midi 55 is 195.8932417187981Hz
# Accourate estimate for midi 56 is 207.80620493773213Hz
# Accourate estimate for midi 57 is 220.19815668202764Hz
# Accourate estimate for midi 58 is 233.2458896423867Hz
# Accourate estimate for midi 59 is 247.07594674402944Hz
# Accourate estimate for midi 60 is 261.76744377625835Hz
# Accourate estimate for midi 61 is 277.3316582914573Hz
# Accourate estimate for midi 62 is 293.62311557788945Hz
# Accourate estimate for midi 63 is 311.09045226130655Hz
# Accourate estimate for midi 64 is 329.5929648241206Hz
# Accourate estimate for midi 65 is 349.14070351758795Hz
# Accourate estimate for midi 66 is 369.89447236180905Hz
# Accourate estimate for midi 67 is 391.88442211055275Hz
# Accourate estimate for midi 68 is 415.45226130653265Hz
# Accourate estimate for midi 69 is 440.1256281407035Hz
# Accourate estimate for midi 70 is 466.26633165829145Hz
# Accourate estimate for midi 71 is 493.83417085427135Hz
# Accourate estimate for midi 72 is 523.1909547738693Hz
# Accourate estimate for midi 73 is 554.2964824120603Hz
# Accourate estimate for midi 74 is 587.1909547738693Hz
# Accourate estimate for midi 75 is 622.0954773869347Hz
# Accourate estimate for midi 76 is 659.0904522613065Hz
# Accourate estimate for midi 77 is 697.5527638190955Hz
# Accourate estimate for midi 78 is 739.0804020100503Hz
# Accourate estimate for midi 79 is 783.1005025125628Hz
# Accourate estimate for midi 80 is 829.6030150753769Hz
# Accourate estimate for midi 81 is 881.643216080402Hz
# Accourate estimate for midi 82 is 931.3517587939698Hz
# Accourate estimate for midi 83 is 987.6130653266332Hz
# Accourate estimate for midi 84 is 1046.1557788944724Hz
# Accourate estimate for midi 85 is 1108.3165829145728Hz
# Accourate estimate for midi 86 is 1174.21608040201Hz
# Accourate estimate for midi 87 is 1244.0954773869346Hz
# Accourate estimate for midi 88 is 1318.175879396985Hz
# Accourate estimate for midi 89 is 1395.9346733668342Hz
# Accourate estimate for midi 90 is 1478.9396984924624Hz
# Accourate estimate for midi 91 is 1566.8994974874372Hz
# Accourate estimate for midi 92 is 1660.0552763819096Hz
# Accourate estimate for midi 93 is 1758.9497487437186Hz
# Accourate estimate for midi 94 is 1863.6030150753768Hz
# Accourate estimate for midi 95 is 1976.467336683417Hz
# Accourate estimate for midi 96 is 2093.994974874372Hz
# Accourate estimate for midi 97 is 2218.5075376884424Hz
# Accourate estimate for midi 98 is 2350.6582914572864Hz
# Accourate estimate for midi 99 is 2490.4170854271356Hz
# Accourate estimate for midi 100 is 2638.5175879396984Hz
# Accourate estimate for midi 101 is 2795.0603015075376Hz
# Accourate estimate for midi 102 is 2961.251256281407Hz
# Accourate estimate for midi 103 is 3137.391959798995Hz
# Accourate estimate for midi 104 is 3324.0150753768844Hz
# Accourate estimate for midi 105 is 3521.6934673366836Hz
# Accourate estimate for midi 106 is 3731.1507537688444Hz
# Accourate estimate for midi 107 is 3953.190954773869Hz

# %% [markdown]
# # 4.4 Reprezentace klavíru

# %%
# Experiment on NOTE 0
# TODO all notes
print(bases[NOTES[0]])
synt_tones = np.zeros([bases.size, 5, 2])

for note in range(MIDIFROM, MIDITO):
    spectrum = np.fft.fft(xall[note])
    for i in range(1, 6):
        d = dtft(bases[note])
        synt_tones[note][i-1][0] = abs(d * i)
        synt_tones[note][i-1][1] =5
        
    if note in NOTES:
        s = np.log10(np.abs(spectrum) ** 2)
        s[0]=0
        fig = plt.figure(figsize=(20, 7))
        ax = fig.add_subplot(111)
        ax.set_title(f"Signal of MIDI {note}")
        ax.set_xlabel(f"Frequency $[Hz]$")
        ax.set_ylabel(f"Mag. $[db]$")
        for index, i in enumerate(synt_tones[note]):
            # Unhinged height hack
            ax.plot(np.real(i), max(abs(s[int(np.real(i))-5: int(np.real(i)+5)])), "ro")
        ax.plot(abs(s[:int(11*bases[note])]))
        ax.grid()
        plt.tight_layout()
    print(synt_tones[note])
# Out:
# 65.57377049180327
# [[ 31.76450512   5.        ]
#  [ 63.52901024   5.        ]
#  [ 95.29351536   5.        ]
#  [127.05802048   5.        ]
#  [158.8225256    5.        ]]
# [[ 33.73227207   5.        ]
#  [ 67.46454414   5.        ]
#  [101.19681621   5.        ]
#  [134.92908828   5.        ]
#  [168.66136035   5.        ]]
# [[ 35.7816092    5.        ]
#  [ 71.56321839   5.        ]
#  [107.34482759   5.        ]
#  [143.12643678   5.        ]
#  [178.90804598   5.        ]]
# [[ 37.96103896   5.        ]
#  [ 75.92207792   5.        ]
#  [113.88311688   5.        ]
#  [151.84415584   5.        ]
#  [189.80519481   5.        ]]
# [[ 40.27257094   5.        ]
#  [ 80.54514187   5.        ]
#  [120.81771281   5.        ]
#  [161.09028375   5.        ]
#  [201.36285469   5.        ]]
